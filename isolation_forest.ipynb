# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
part_1 = pd.read_csv("LWB_Monthly_data.csv")

# %%
ori_data = part_1.drop(['_key_client_id', '_key_occurreddate_month', 'response_variable'], axis=1)

import sklearn.preprocessing as preprocessing
scaler = preprocessing.StandardScaler()

for column in ori_data.columns:
      scale_param = scaler.fit(ori_data[column].values.reshape(-1, 1))
      ori_data[column] = scaler.fit_transform(ori_data[column].values.reshape(-1, 1), scale_param)

# %%
ori_data['_key_client_id'] = part_1['_key_client_id']
ori_data['_key_occurreddate_month'] = part_1['_key_occurreddate_month']
ori_data['response_variable'] = part_1['response_variable']

# %%
init_record = ori_data 
init_record = init_record.set_index(['_key_client_id', '_key_occurreddate_month'])
init_record.head(10)
# Out:
#                                                               incident_catgry_care_concern_piv  \
# _key_client_id                       _key_occurreddate_month
# 0000D172-EA88-432F-8235-9FAA00D29072 2019-04-01                                      -0.064032
#                                      2019-05-01                                      -0.064032
#                                      2019-06-01                                      -0.064032
#                                      2019-07-01                                      -0.064032
#                                      2019-08-01                                      -0.064032
#                                      2019-09-01                                      -0.064032
#                                      2019-10-01                                      -0.064032
#                                      2019-11-01                                      -0.064032
# ...

# %%
part_2 = pd.read_csv("LWB_monthly_test.csv")
ori_data = part_2.drop(['_key_client_id', '_key_occurreddate_month', 'response_variable'], axis=1)

import sklearn.preprocessing as preprocessing
scaler = preprocessing.StandardScaler()

for column in ori_data.columns:
      scale_param = scaler.fit(ori_data[column].values.reshape(-1, 1))
      ori_data[column] = scaler.fit_transform(ori_data[column].values.reshape(-1, 1), scale_param)
ori_data['_key_client_id'] = part_2['_key_client_id']
ori_data['_key_occurreddate_month'] = part_2['_key_occurreddate_month']
ori_data['response_variable'] = part_2['response_variable']
test_record = ori_data 
test_record = test_record.set_index(['_key_client_id', '_key_occurreddate_month'])
test_record.head(10)
# Out:
#                                                               incident_catgry_care_concern_piv  \
# _key_client_id                       _key_occurreddate_month
# 401EC809-2E46-4DE5-A95A-D96EC6AC0772 2019-04-01                                      -0.070337
#                                      2019-05-01                                      -0.070337
#                                      2019-06-01                                      -0.070337
#                                      2019-07-01                                      -0.070337
#                                      2019-08-01                                      -0.070337
#                                      2019-09-01                                      -0.070337
#                                      2019-10-01                                      -0.070337
#                                      2019-11-01                                      -0.070337
# ...

# %% [markdown]
# # Try reduce columns

# %%
#selected = pd.concat([init_record.filter(regex=r'allrows', axis=1), init_record["response_variable"]], axis = 1)
#selected = init_record.drop(init_record.filter(regex=r'allrows', axis=1),axis = 1)
#selected

# %%
def construct_feature_label(data):
    y = []
    clientList = list(set(data.index.get_level_values(0)))
    data['response_variable'] = data.groupby(level=0)['response_variable'].shift(-1)  
    data = data.groupby(level=0, as_index=False).apply(lambda group: group.iloc[:-1])
    #print(data.loc["0000D172-EA88-432F-8235-9FAA00D29072"]['response_variable'])
    y = data['response_variable']
    x = data.drop('response_variable',axis='columns')
    return x, y

feature, label = construct_feature_label(init_record)

# %%
test_feature, test_label = construct_feature_label(test_record)

# %%
feature
# Out:
#                                                                     incident_catgry_care_concern_piv  \
#       _key_client_id                       _key_occurreddate_month
# 0     0000D172-EA88-432F-8235-9FAA00D29072 2019-04-01                                      -0.064032
#                                            2019-05-01                                      -0.064032
#                                            2019-06-01                                      -0.064032
#                                            2019-07-01                                      -0.064032
#                                            2019-08-01                                      -0.064032
# ...                                                                                              ...
# 12321 FFFF7C4D-F6DD-46D0-A9C0-AE3C2DC51132 2019-08-01                                      -0.064032
#                                            2019-09-01                                      -0.064032
# ...

# %%
label
# Out:
#        _key_client_id                        _key_occurreddate_month
# 0      0000D172-EA88-432F-8235-9FAA00D29072  2019-04-01                 0.0
#                                              2019-05-01                 0.0
#                                              2019-06-01                 0.0
#                                              2019-07-01                 0.0
#                                              2019-08-01                 0.0
#                                                                        ...
# 12321  FFFF7C4D-F6DD-46D0-A9C0-AE3C2DC51132  2019-08-01                 0.0
#                                              2019-09-01                 0.0
#                                              2019-10-01                 0.0
#                                              2019-11-01                 0.0
#                                              2019-12-01                 0.0
# Name: response_variable, Length: 99414, dtype: float64

# %%
train_data = feature
train_target = label
from sklearn.model_selection import train_test_split

train_X,test_X, train_y, test_y = train_test_split(train_data,
                                                   train_target,
                                                   test_size = 0.25,
                                                   random_state = 0)

# %%
train_X['label'] = train_y
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
outliers_train = pd.DataFrame()
for index, row in train_X.iterrows():
    if row['label']==1:
        outliers_train = outliers_train.append(row)
outliers_train
# Out:
#                                                     13 to 17  18 to 24  \
# (11090, E5D276C1-C79C-48F5-AF23-5245BB402073, 2... -0.408378 -0.389431
# (2868, 3B02881E-B03E-4EDC-861F-19E899B79EDE, 20... -0.408378 -0.389431
# (6404, 84E87B9C-5B8A-4183-B5FB-3041616E6E40, 20... -0.408378 -0.389431
# (1087, 15D97D09-3D06-4993-A36A-A5B60104E77B, 20... -0.408378 -0.389431
# (7325, 98BF1479-8C94-4146-9F48-A91200A7E9DC, 20... -0.408378  2.567851
# ...                                                      ...       ...
# (10421, D8407124-6374-4365-9642-A52C00F9D0B3, 2... -0.408378 -0.389431
# (10101, D2313D02-5946-4DDA-B32B-6F1A5FFA31F1, 2... -0.408378 -0.389431
# (9888, CDC2C7CD-030C-4A1D-8B05-7CA6F0019CA4, 20... -0.408378 -0.389431
# (1087, 15D97D09-3D06-4993-A36A-A5B60104E77B, 20... -0.408378 -0.389431
# (7649, 9F39D05D-A441-4B7E-8C4F-A9EC00FA70B6, 20...  2.448710 -0.389431
#
#                                                     25 to 34  35 to 44  \
# ...

# %%
normal_train = train_X.drop(outliers_train.reset_index()['index'].tolist())
normal_train
# Out:
#                                                                     incident_catgry_care_concern_piv  \
#       _key_client_id                       _key_occurreddate_month
# 11828 F5219DBD-47B3-4083-83B6-A68300BD0AE4 2019-09-01                                      -0.064032
# 176   035D8088-5BB5-4296-82C3-A92E00E8B466 2019-04-01                                      -0.064032
# 12266 FEAF6FE1-C6D7-4681-8548-A8DB00C5F61E 2019-06-01                                      -0.064032
# 6182  7FEA2072-3804-4EF2-B66C-A43600CA7F0C 2019-07-01                                      -0.064032
# 9104  BD6F803A-F2B2-42C6-A7EE-AA8B00E17EC8 2019-12-01                                      -0.064032
# ...                                                                                              ...
# 2646  3671481D-9597-4645-870D-AA2900BB1586 2019-09-01                                      -0.064032
# 5724  7553A27A-84D5-4407-AA8C-A3E900A8B4B9 2019-06-01                                      -0.064032
# ...

# %%
normal_train.reset_index(drop = True)
# Out:
#        incident_catgry_care_concern_piv  incident_catgry_medication_piv  \
# 0                             -0.064032                       -0.067066
# 1                             -0.064032                       -0.067066
# 2                             -0.064032                       -0.067066
# 3                             -0.064032                       -0.067066
# 4                             -0.064032                       -0.067066
# ...                                 ...                             ...
# 69010                         -0.064032                       -0.067066
# 69011                         -0.064032                       -0.067066
# 69012                         -0.064032                       -0.067066
# 69013                         -0.064032                       -0.067066
# 69014                         -0.064032                       -0.067066
#
#        incident_catgry_medical_piv  incident_catgry__piv  \
# ...

# %%
test_X['label'] = test_y
outliers_test = pd.DataFrame()
for index, row in test_X.iterrows():
    if row['label']==1:
        outliers_test = outliers_test.append(row)
outliers_test
# Out:
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                     13 to 17  18 to 24  \
# (12217, FD6384D9-4DA7-E011-B4AF-B6A03279A8B3, 2...  2.448710 -0.389431
# (5164, 69E95CD5-789B-4104-9276-9F6900C84F69, 20... -0.408378 -0.389431
# (9318, C206ED69-1506-41BC-8DE1-E98BF4F74B08, 20... -0.408378 -0.389431
# (8113, A8DFA934-4D02-4CC2-8621-A99D00FCE9FF, 20... -0.408378 -0.389431
# (1975, 28BEE270-485F-4F5C-BBC3-A05901163617, 20... -0.408378 -0.389431
# ...                                                      ...       ...
# (9853, CCF7ABA1-592A-44F3-8D5D-A69100E563DC, 20... -0.408378  2.567851
# ...

# %%
normal_test = test_X.drop(outliers_test.reset_index()['index'].tolist())
normal_test
# Out:
#                                                                     incident_catgry_care_concern_piv  \
#       _key_client_id                       _key_occurreddate_month
# 9589  C76F18BC-B7DD-47AB-9CA7-A7BC00DE981F 2019-07-01                                      -0.064032
# 8843  B81A1EB2-2859-4516-9DDC-A2EC015B421C 2020-02-01                                      -0.064032
# 4513  5C706481-D84A-464F-B51E-A8B000BD1DBC 2019-11-01                                      -0.064032
# 2313  2FB7A9E8-FE72-4D0A-8532-AA9F0128BD66 2019-08-01                                      -0.064032
# 5035  6781FC3E-DE1E-41A5-A58A-A2F300BE5EB8 2019-05-01                                      -0.064032
# ...                                                                                              ...
# 908   1235B230-DD8D-4002-B685-A92E00D4F107 2019-11-01                                      -0.064032
# 9862  CD1399A6-F6AB-48F3-92C2-A6BB01080139 2019-06-01                                      -0.064032
# ...

# %%
normal_test.reset_index(drop = True)
# Out:
#        incident_catgry_care_concern_piv  incident_catgry_medication_piv  \
# 0                             -0.064032                       -0.067066
# 1                             -0.064032                       -0.067066
# 2                             -0.064032                       -0.067066
# 3                             -0.064032                       -0.067066
# 4                             -0.064032                       -0.067066
# ...                                 ...                             ...
# 23044                         -0.064032                       -0.067066
# 23045                         -0.064032                       -0.067066
# 23046                         -0.064032                       -0.067066
# 23047                         -0.064032                       -0.067066
# 23048                         -0.064032                       -0.067066
#
#        incident_catgry_medical_piv  incident_catgry__piv  \
# ...

# %%
test_final = outliers_test.append(normal_test.sample(2046))

# %%
test_final = test_final.sample(frac=1).reset_index(drop=True)

# %%
test_feature['label'] = test_label
new_test = test_feature.append(outliers_train)
new_test = new_test.reset_index(drop=True)

# %%
new_test = new_test.sample(frac=1)

# %%
new_test = new_test.reset_index()
new_test
# Out:
#        index  incident_catgry_care_concern_piv  \
# 0       8776                         -0.070337
# 1      13997                         -0.064032
# 2      15875                         -0.064032
# 3      14777                         -0.064032
# 4        563                         -0.070337
# ...      ...                               ...
# 16032  14598                         -0.064032
# 16033  14004                         -0.064032
# 16034   1228                         -0.070337
# 16035  10833                         -0.064032
# 16036   2464                         -0.070337
#
#        incident_catgry_medication_piv  incident_catgry_medical_piv  \
# 0                           -0.077996                    -0.111546
# 1                           -0.067066                    -0.103339
# 2                           -0.067066                    -0.103339
# 3                           -0.067066                    -0.103339
# ...

# %%
#测试集预测

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score, confusion_matrix, roc_curve,accuracy_score

# %%
ifmodel = IsolationForest(n_estimators=100, max_samples=1000, contamination=float(0.02),max_features= 1.0)
ifmodel.fit(normal_train.drop(['label'],axis=1))
pred_label = ifmodel.predict(test_X.drop(['label'],axis=1))
df_comp = pd.DataFrame()
df_comp['anomaly']= pred_label
df_comp['y'] = np.array(test_y)

df_comp['anomaly'].replace(1, 0,inplace = True)
df_comp['anomaly'].replace(-1, 1,inplace = True)

# %%
ifmodel.decision_function(test_X.drop(['label'],axis=1))
# Out:
# array([0.07458052, 0.07241425, 0.07366388, ..., 0.07600174, 0.08021455,
#        0.07380373])

# %%
ifmodel = IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.05),max_features= 500)
ifmodel.fit(normal_train.drop(['label'],axis=1))
pred_label = ifmodel.predict(new_test.drop(['label','index'],axis=1))
df_comp = pd.DataFrame()
df_comp['anomaly']= pred_label
df_comp['y'] = np.array(new_test['label'])

df_comp['anomaly'].replace(1, 0,inplace = True)
df_comp['anomaly'].replace(-1, 1,inplace = True)

# %%
df_comp['index'] = new_test['index']
df_comp
# Out:
#        anomaly    y  index
# 0            0  0.0   8776
# 1            1  1.0  13997
# 2            0  1.0  15875
# 3            1  1.0  14777
# 4            0  0.0    563
# ...        ...  ...    ...
# 16032        1  1.0  14598
# 16033        0  1.0  14004
# 16034        0  0.0   1228
# 16035        0  1.0  10833
# 16036        0  0.0   2464
#
# [16037 rows x 3 columns]

# %%
temp = []
for index, row in df_comp.iterrows():
    if row['index'] in range(10492,16037):
        temp.append(index)
temp
# Out:
# [1,
#  2,
#  3,
#  17,
#  19,
#  21,
#  26,
#  31,
#  34,
#  38,
#  41,
#  42,
#  54,
#  55,
#  56,
#  57,
#  61,
#  63,
#  67,
#  69,
#  70,
#  71,
#  77,
#  79,
#  80,
#  92,
#  95,
#  97,
#  99,
#  101,
#  103,
#  104,
#  106,
#  112,
#  117,
#  120,
#  130,
#  131,
#  138,
#  140,
#  142,
#  143,
#  146,
#  147,
#  152,
#  153,
#  156,
#  158,
#  165,
#  167,
#  170,
#  173,
#  174,
#  175,
#  177,
#  182,
#  185,
#  193,
#  194,
#  196,
#  197,
#  198,
#  200,
#  202,
#  204,
#  205,
#  211,
#  213,
#  214,
#  215,
#  216,
#  218,
#  219,
#  220,
#  221,
#  225,
#  227,
#  229,
#  230,
#  233,
#  234,
#  235,
#  237,
#  238,
#  241,
#  242,
#  249,
#  250,
#  264,
#  266,
#  267,
#  268,
#  269,
#  276,
#  278,
#  279,
#  281,
#  290,
#  292,
#  296,
#  303,
#  305,
#  312,
#  313,
#  314,
#  316,
#  318,
#  321,
#  322,
#  325,
#  328,
#  330,
#  331,
#  335,
#  337,
#  341,
#  343,
#  347,
#  348,
#  352,
#  362,
#  365,
#  368,
#  369,
#  370,
#  371,
#  373,
#  376,
#  379,
# ...

# %%
df_comp = df_comp.drop(temp)

# %%
clf = IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.05),max_features= 50)
clf.fit(normal_train.drop(['label'],axis=1))
pred_label = clf.predict(test_final.drop(['label'],axis=1))
df_comp = pd.DataFrame()
df_comp['anomaly']= pred_label
df_comp['y'] = np.array(test_final['label'])
df_comp
df_comp['anomaly'].replace(1, 0,inplace = True)
df_comp['anomaly'].replace(-1, 1,inplace = True)

# %%
df_comp
# Out:
#       anomaly    y
# 0           0  0.0
# 1           0  0.0
# 2           0  0.0
# 3           0  1.0
# 4           0  0.0
# ...       ...  ...
# 3846        0  0.0
# 3847        0  0.0
# 3848        0  0.0
# 3849        0  1.0
# 3850        0  0.0
#
# [3851 rows x 2 columns]

# %%
from sklearn.metrics import classification_report

report = classification_report(df_comp['y'], df_comp['anomaly'], labels=[0,1])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93     23049
#            1       0.31      0.57      0.40      1805
#
#     accuracy                           0.88     24854
#    macro avg       0.64      0.73      0.67     24854
# weighted avg       0.92      0.88      0.89     24854

# %%
from sklearn.svm import OneClassSVM

# %%
model = OneClassSVM(kernel="rbf", gamma="scale", tol=1e-6)
model.fit(normal_train.drop(['label'],axis=1))
# Out:
# OneClassSVM(cache_size=200, coef0=0.0, degree=3, gamma='scale', kernel='rbf',
#             max_iter=-1, nu=0.5, shrinking=True, tol=1e-06, verbose=False)

# %%
pred_label = model.predict(test_final.drop(['label'],axis=1))
df_comp = pd.DataFrame()
df_comp['anomaly']= pred_label
df_comp['y'] = np.array(test_final['label'])
df_comp
df_comp['anomaly'].replace(1, 0,inplace = True)
df_comp['anomaly'].replace(-1, 1,inplace = True)
df_comp
# Out:
#       anomaly    y
# 0           1  0.0
# 1           1  0.0
# 2           1  1.0
# 3           1  0.0
# 4           1  1.0
# ...       ...  ...
# 4087        1  1.0
# 4088        1  1.0
# 4089        1  1.0
# 4090        1  1.0
# 4091        1  0.0
#
# [4092 rows x 2 columns]

# %%
from sklearn.metrics import classification_report

report = classification_report(df_comp['y'], df_comp['anomaly'], labels=[0,1])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      2046
#            1       0.50      1.00      0.67      2046
#
#     accuracy                           0.50      4092
#    macro avg       0.25      0.50      0.33      4092
# weighted avg       0.25      0.50      0.33      4092
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
new_test['label']
# Out:
# 0        0.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0
#         ...
# 16032    1.0
# 16033    1.0
# 16034    0.0
# 16035    1.0
# 16036    0.0
# Name: label, Length: 16037, dtype: float64

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
explainer = shap.TreeExplainer(clf)

# %%
shap_values = explainer.shap_values(new_test.drop(['label','index'],axis=1))

# %%
shap.force_plot(explainer.expected_value, shap_values[1,:], new_test.drop(['label','index'],axis=1).iloc[1,:])
# Out:
# <div id='i7MWXOCG6UHZOCCB7ZFNG'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.force_plot(explainer.expected_value, shap_values[0:10,:], new_test.drop(['label','index'],axis=1).iloc[0:10,:])
# Out:
# <div id='i0DHDKEL606Z4JRA7JYF2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
shap.summary_plot(shap_values, new_test.drop(['label','index'],axis=1),max_display=10)

# %%
shap.summary_plot(shap_values, new_test.drop(['label','index'],axis=1),max_display=10 ,plot_type="bar")

# %%
shap.dependence_plot("incident_catgry_media_piv", shap_values, new_test.drop(['label','index'],axis=1))

# %%
import time

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from sklearn import svm
from sklearn.datasets import make_moons, make_blobs
from sklearn.covariance import EllipticEnvelope
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

print(__doc__)

matplotlib.rcParams['contour.negative_linestyle'] = 'solid'

# Example settings
n_samples = 300
outliers_fraction = 0.15
n_outliers = int(outliers_fraction * n_samples)
n_inliers = n_samples - n_outliers

# define outlier/anomaly detection methods to be compared
anomaly_algorithms = [
    ("Robust covariance", EllipticEnvelope(contamination=outliers_fraction)),
    ("One-Class SVM", svm.OneClassSVM(nu=outliers_fraction, kernel="rbf",
                                      gamma=0.1)),
    ("Isolation Forest", IsolationForest(contamination=outliers_fraction,
                                         random_state=42)),
    ("Local Outlier Factor", LocalOutlierFactor(
        n_neighbors=35, contamination=outliers_fraction))]

# Define datasets
blobs_params = dict(random_state=0, n_samples=n_inliers, n_features=2)
datasets = [
    make_blobs(centers=[[0, 0], [0, 0]], cluster_std=0.5,
               **blobs_params)[0],
    make_blobs(centers=[[2, 2], [-2, -2]], cluster_std=[0.5, 0.5],
               **blobs_params)[0],
    make_blobs(centers=[[2, 2], [-2, -2]], cluster_std=[1.5, .3],
               **blobs_params)[0],
    4. * (make_moons(n_samples=n_samples, noise=.05, random_state=0)[0] -
          np.array([0.5, 0.25])),
    14. * (np.random.RandomState(42).rand(n_samples, 2) - 0.5)]

# Compare given classifiers under given settings
xx, yy = np.meshgrid(np.linspace(-7, 7, 150),
                     np.linspace(-7, 7, 150))

plt.figure(figsize=(len(anomaly_algorithms) * 2 + 3, 12.5))
plt.subplots_adjust(left=.02, right=.98, bottom=.001, top=.96, wspace=.05,
                    hspace=.01)

plot_num = 1
rng = np.random.RandomState(42)

for i_dataset, X in enumerate(datasets):
    # Add outliers
    X = np.concatenate([X, rng.uniform(low=-6, high=6,
                       size=(n_outliers, 2))], axis=0)

    for name, algorithm in anomaly_algorithms:
        t0 = time.time()
        algorithm.fit(X)
        t1 = time.time()
        plt.subplot(len(datasets), len(anomaly_algorithms), plot_num)
        if i_dataset == 0:
            plt.title(name, size=18)

        # fit the data and tag outliers
        if name == "Local Outlier Factor":
            y_pred = algorithm.fit_predict(X)
        else:
            y_pred = algorithm.fit(X).predict(X)

        # plot the levels lines and the points
        if name != "Local Outlier Factor":  # LOF does not implement predict
            Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])
            Z = Z.reshape(xx.shape)
            plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='black')

        colors = np.array(['#377eb8', '#ff7f00'])
        plt.scatter(X[:, 0], X[:, 1], s=10, color=colors[(y_pred + 1) // 2])

        plt.xlim(-7, 7)
        plt.ylim(-7, 7)
        plt.xticks(())
        plt.yticks(())
        plt.text(.99, .01, ('%.2fs' % (t1 - t0)).lstrip('0'),
                 transform=plt.gca().transAxes, size=15,
                 horizontalalignment='right')
        plot_num += 1

plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
clf = IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.05),max_features= 50)
clf.fit(normal_train.drop(['label'],axis=1))
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.05,
#                 max_features=50, max_samples='auto', n_estimators=50,
#                 n_jobs=None, random_state=None, verbose=0, warm_start=False)

# %%
pred_label = clf.predict(test_X.drop(['label'],axis=1))

# %%
df_comp = pd.DataFrame()
df_comp['anomaly']= pred_label
df_comp['y'] = np.array(test_y)
df_comp
# Out:
#        anomaly    y
# 0            1  0.0
# 1            1  0.0
# 2            1  0.0
# 3            1  0.0
# 4            1  0.0
# ...        ...  ...
# 24849        1  0.0
# 24850        1  0.0
# 24851        1  0.0
# 24852        1  0.0
# 24853        1  0.0
#
# [24854 rows x 2 columns]

# %%
#df_comp = pd.DataFrame()
#df_comp['anomaly']= pred_label
#df_comp['y'] = np.array(outliers_test['label'])
#df_comp

# %%
df_comp['anomaly'].replace(1, 0,inplace = True)
df_comp['anomaly'].replace(-1, 1,inplace = True)

# %%
df_comp
# Out:
#        anomaly    y
# 0            0  0.0
# 1            0  0.0
# 2            0  0.0
# 3            0  0.0
# 4            0  0.0
# ...        ...  ...
# 24849        0  0.0
# 24850        0  0.0
# 24851        0  0.0
# 24852        0  0.0
# 24853        0  0.0
#
# [24854 rows x 2 columns]

# %%
t = 0
total=0
for index, row in df_comp.iterrows():
    if row['anomaly']==1 and row['y']==1:
        t = t+1
    if row['y']==1:
        total = total+1
t/total
# Out:
# 0.4038781163434903

# %%
t
# Out:
# 729

# %%
from sklearn.metrics import classification_report

report = classification_report(df_comp['y'], df_comp['anomaly'], labels=[0,1])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95     23049
#            1       0.42      0.43      0.42      1805
#
#     accuracy                           0.92     24854
#    macro avg       0.69      0.69      0.69     24854
# weighted avg       0.92      0.92      0.92     24854

# %%
confusion_matrix(df_comp['anomaly'],df_comp['y'])
# Out:
# array([[22426,  1225],
#        [  623,   580]], dtype=int64)

# %% [markdown]
# # PCA

# %%
from sklearn import decomposition

# %%
#pca = decomposition.PCA(n_components=0.9)
#feature_pca = pca.fit_transform(feature)

# %% [markdown]
# # Model

# %%
from sklearn.ensemble import IsolationForest
from sklearn.metrics import f1_score, confusion_matrix, roc_curve,accuracy_score

# %%
feature
# Out:
#                                                                     incident_catgry_care_concern_piv  \
#       _key_client_id                       _key_occurreddate_month
# 0     0000D172-EA88-432F-8235-9FAA00D29072 2019-04-01                                              0
#                                            2019-05-01                                              0
#                                            2019-06-01                                              0
#                                            2019-07-01                                              0
#                                            2019-08-01                                              0
# ...                                                                                              ...
# 13404 FFFF7C4D-F6DD-46D0-A9C0-AE3C2DC51132 2019-08-01                                              0
#                                            2019-09-01                                              0
# ...

# %%
model=IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.05),max_features= 50)
model.fit(feature)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.05,
#                 max_features=50, max_samples='auto', n_estimators=50,
#                 n_jobs=None, random_state=None, verbose=0, warm_start=False)

# %%
y_hat = model.predict(feature)

# %%
y_hat = np.where(y_hat == -1, 1, 0)

# %%
report = classification_report(label, y_hat, labels=[0,1])
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96    101723
#            1       0.52      0.35      0.42      8183
#
#     accuracy                           0.93    109906
#    macro avg       0.74      0.66      0.69    109906
# weighted avg       0.92      0.93      0.92    109906
