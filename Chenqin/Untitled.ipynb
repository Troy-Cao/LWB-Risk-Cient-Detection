# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("20200404_LWB_Client_Events_Day.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/envs/sem1_2020/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# ~/opt/anaconda3/envs/sem1_2020/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1564
# -> 1565 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1566     """
#
# KeyboardInterrupt:
#
# ...

# %%
print(data.head)

# %%
head = pandas.read_csv("20200404_LWB_Client_Events_Day.csv", nrows=1).columns

# %%
pandas.read_csv("20200404_LWB_Client_Events_Day.csv", nrows=100)
# Out:
#                           _key_client_id  _key_occurreddate_day  \
# 0   00083605-BF0D-4109-BB00-AA8101120642  2019-07-05T00:00:00.0
# 1   00083605-BF0D-4109-BB00-AA8101120642  2019-07-06T00:00:00.0
# 2   00083605-BF0D-4109-BB00-AA8101120642  2019-07-07T00:00:00.0
# 3   00083605-BF0D-4109-BB00-AA8101120642  2019-07-08T00:00:00.0
# 4   00083605-BF0D-4109-BB00-AA8101120642  2019-07-09T00:00:00.0
# ..                                   ...                    ...
# 95  001D6DB5-1D88-E011-A5C6-B6A03279A8B3  2019-04-30T00:00:00.0
# 96  001D6DB5-1D88-E011-A5C6-B6A03279A8B3  2019-05-01T00:00:00.0
# 97  001D6DB5-1D88-E011-A5C6-B6A03279A8B3  2019-05-02T00:00:00.0
# 98  001D6DB5-1D88-E011-A5C6-B6A03279A8B3  2019-05-03T00:00:00.0
# 99  001D6DB5-1D88-E011-A5C6-B6A03279A8B3  2019-05-04T00:00:00.0
#
#     occurreddate_monthofyear  incident_catgry__piv  \
# 0                          7                     0
# 1                          7                     0
# ...

# %%
len(head)
# Out:
# 1181
