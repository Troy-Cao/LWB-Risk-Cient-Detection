# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plot
month = pd.read_csv(r'C:\Users\yun liu\Desktop\LWBProject\Month.csv',low_memory=False)

# %%
model=pd.DataFrame() # make a new dataframe for simple attributes.
month['PrimaryKey'] = month.index
pkey=month.iloc[:,-1]

# %%
data=month.filter(regex=r'^(_|occurreddate_|rowtype_|medc_|status_)', axis=1)
ckey=month.iloc[:,0:2]
dataset=data.loc[:,~data.columns.str.contains('lag02|lag03|lag04|lag05|lag06|_hash|_id')]
dataset=dataset.copy()

# %% [raw]
# Data that start with '_', 5 columns, first 2 are compose keys. The last 3 columns are store in 'data1m', scatter plot each pair. Aggregate by month. We can simplify the 3 columns to one column with 0 or 1.

# %%
data1=dataset.filter(regex=r'^_', axis=1)
data1m=data1.iloc[:,1:4]
data1m['key']=pkey
data1m.plot.scatter(x='_dependent_incident_severity_minor_piv', y='_dependent_incident_severity_critical_piv',color='Blue',title='Minor VS Critical')

# %% [raw]
# From this plot, we can kown that the range of 'minor' is [0,31] and the range of 'Critical' is [0,6], this two attributs are has a kinds of neigative relation at the diagnal of the plots. Maybe large minor means lower Crtical and vice versa.

# %%
data1m.plot.scatter(x='_dependent_incident_severity_minor_piv', y='_dependent_incident_severity_severe_piv',color='Red',title='Minor VS Servere')

# %% [raw]
# From this plot, we can know that 'server' with range [0,69] and has a neigative correlation with 'minor' when data near the diagnal. Maybe large minor means lower Sever and vice versa.

# %%
data1m.plot.scatter(x='_dependent_incident_severity_critical_piv', y='_dependent_incident_severity_severe_piv',title='Critical VS Severe')

# %% [raw]
# From this plot, we can see that 'severe' is independent to 'Critical'

# %%
data1m.iloc[:,0:3].corr()
# Out:
#                                            _dependent_incident_severity_critical_piv  \
# _dependent_incident_severity_critical_piv                                   1.000000
# _dependent_incident_severity_minor_piv                                      0.138081
# _dependent_incident_severity_severe_piv                                     0.177137
#
#                                            _dependent_incident_severity_minor_piv  \
# _dependent_incident_severity_critical_piv                                0.138081
# _dependent_incident_severity_minor_piv                                   1.000000
# _dependent_incident_severity_severe_piv                                  0.306229
#
#                                            _dependent_incident_severity_severe_piv
# _dependent_incident_severity_critical_piv                                 0.177137
# _dependent_incident_severity_minor_piv                                    0.306229
# _dependent_incident_severity_severe_piv                                   1.000000

# %% [raw]
# In the project demonstration, we know that the respose is whether the incident happend or not, and from the "_dependent_incident_severity_" columns we can get a response for the model. SQL provided by client for response is:
# WHEN _dependent_incident_severity_critical_piv > 0 OR _dependent_incident_severity_severe_piv > 0 THEN 'event'
# ELSE 'non-event' END AS dependent_critical_severe. the following code is for finding the response.

# %%
response=[]
numR=data1m.shape[0]
con=0
coun=0
for i in range(numR):
    severe=data1m.loc[i,'_dependent_incident_severity_severe_piv']
    critical=data1m.loc[i,'_dependent_incident_severity_critical_piv']
    if severe>0 or critical>0:
        response.append(1)
        coun+=1
    else:
        response.append(0)
        con+=1
model['Incident']=response
model['Incident'].value_counts()
# Out:
# 0    119707
# 1      4586
# Name: Incident, dtype: int64

# %%
Now I am moving to the data which column name start with "occurreddate".

# %%
data2=dataset.filter(regex=r'^occurreddate_', axis=1)
data2.columns
# Out:
# Index(['occurreddate_monthofyear', 'occurreddate_weekofyear',
#        'occurreddate_dayofweek', 'occurreddate_dayofmonth',
#        'occurreddate_dayofyear'],
#       dtype='object')

# %%
From the column names we can know that, this columns stores the Date information, which can be treated as description.

The following data I am gone to analysis is the columns with name start at 'rowtype'

# %%
data3=dataset.filter(regex=r'^rowtype_', axis=1)
#data3.columns

# %% [raw]
# according to the suffix of the column names, 5 groups this data to small datasets: end with "_piv", "_sum_n_days", "_avg_n_days", "_days_since", "_lag01". these attributes can scale the response.

# %%
data3piv=data3.filter(regex=r'_piv$', axis=1) #16 rows aggregate by one month
#data3piv.dtypes
data3piv.describe()
# Out:
#        rowtype_client_address_addition_piv  rowtype_rp_end_piv  \
# count                        124293.000000       124293.000000
# mean                              0.039914            0.003347
# std                               0.200388            0.094698
# min                               0.000000            0.000000
# 25%                               0.000000            0.000000
# 50%                               0.000000            0.000000
# 75%                               0.000000            0.000000
# max                               4.000000           10.000000
#
#        rowtype_rp_start_piv  rowtype_progress_note_piv  rowtype_diagnosis_piv  \
# count         124293.000000              124293.000000          124293.000000
# mean               0.005318                   5.855342               0.031450
# std                0.107767                  16.578656               0.268733
# min                0.000000                   0.000000               0.000000
# 25%                0.000000                   0.000000               0.000000
# 50%                0.000000                   1.000000               0.000000
# 75%                0.000000                   4.000000               0.000000
# max                8.000000                 303.000000              16.000000
#
#        rowtype_medictn_start_piv  rowtype_client_plan_start_piv  \
# count              124293.000000                  124293.000000
# mean                    0.022970                       0.147281
# std                     0.268184                       0.561807
# min                     0.000000                       0.000000
# 25%                     0.000000                       0.000000
# 50%                     0.000000                       0.000000
# 75%                     0.000000                       0.000000
# max                    18.000000                      74.000000
#
#        rowtype_client_plan_end_piv  rowtype_keyworker_change_piv  \
# count                124293.000000                 124293.000000
# mean                      0.049528                      0.034604
# std                       0.386751                      0.237556
# min                       0.000000                      0.000000
# 25%                       0.000000                      0.000000
# 50%                       0.000000                      0.000000
# 75%                       0.000000                      0.000000
# max                      40.000000                      7.000000
#
#        rowtype_reference_piv  rowtype_medictn_end_piv  \
# count          124293.000000            124293.000000
# mean               27.861706                 0.009864
# std                 8.041660                 0.167614
# min                 1.000000                 0.000000
# 25%                29.000000                 0.000000
# 50%                30.000000                 0.000000
# 75%                31.000000                 0.000000
# max                93.000000                16.000000
#
#        rowtype_plcment_end_piv  rowtype_incident_piv  \
# count            124293.000000         124293.000000
# mean                  0.035521              0.173912
# std                   0.276235              1.044579
# min                   0.000000              0.000000
# 25%                   0.000000              0.000000
# 50%                   0.000000              0.000000
# 75%                   0.000000              0.000000
# max                  12.000000             68.000000
#
#        rowtype_plcment_start_piv  \
# count              124293.000000
# mean                    0.045353
# std                     0.326864
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     0.000000
# max                    13.000000
#
#        rowtype_program_primary_service_type_start_piv  \
# count                                   124293.000000
# mean                                         0.024933
# std                                          0.183380
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                         12.000000
#
#        rowtype_client_alert_start_piv
# count                   124293.000000
# mean                         0.009880
# std                          0.100038
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          2.000000

# %%
data3sum=data3.filter(regex=r'_sum_n_days$', axis=1) #16 rows aggregate by 6 month
#data3sum.dtypes
data3sum.describe()
# Out:
#        rowtype_client_address_addition_piv_sum_n_days  \
# count                                   124250.000000
# mean                                         0.223726
# std                                          0.429880
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          4.000000
#
#        rowtype_rp_end_piv_sum_n_days  rowtype_rp_start_piv_sum_n_days  \
# count                  124250.000000                    124250.000000
# mean                        0.020491                         0.031445
# std                         0.261614                         0.308905
# min                         0.000000                         0.000000
# 25%                         0.000000                         0.000000
# 50%                         0.000000                         0.000000
# 75%                         0.000000                         0.000000
# max                        18.000000                        14.000000
#
#        rowtype_progress_note_piv_sum_n_days  rowtype_diagnosis_piv_sum_n_days  \
# count                         124250.000000                     124250.000000
# mean                              29.557594                          0.152491
# std                               85.590193                          0.592944
# min                                0.000000                          0.000000
# 25%                                1.000000                          0.000000
# 50%                                7.000000                          0.000000
# 75%                               19.000000                          0.000000
# max                             1497.000000                         16.000000
#
#        rowtype_medictn_start_piv_sum_n_days  \
# count                         124250.000000
# mean                               0.128781
# std                                0.830055
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               39.000000
#
#        rowtype_client_plan_start_piv_sum_n_days  \
# count                             124250.000000
# mean                                   0.809513
# std                                    1.669310
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    1.000000
# max                                   76.000000
#
#        rowtype_client_plan_end_piv_sum_n_days  \
# count                           124250.000000
# mean                                 0.252668
# std                                  1.004500
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                 42.000000
#
#        rowtype_keyworker_change_piv_sum_n_days  \
# count                            124250.000000
# mean                                  0.203268
# std                                   0.570972
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   7.000000
#
#        rowtype_reference_piv_sum_n_days  rowtype_medictn_end_piv_sum_n_days  \
# count                     124250.000000                       124250.000000
# mean                         145.753948                            0.054262
# std                           57.892925                            0.472336
# min                            1.000000                            0.000000
# 25%                          119.000000                            0.000000
# 50%                          183.000000                            0.000000
# 75%                          184.000000                            0.000000
# max                          549.000000                           20.000000
#
#        rowtype_plcment_end_piv_sum_n_days  rowtype_incident_piv_sum_n_days  \
# count                       124250.000000                    124250.000000
# mean                             0.195396                         0.941199
# std                              1.250731                         4.694304
# min                              0.000000                         0.000000
# 25%                              0.000000                         0.000000
# 50%                              0.000000                         0.000000
# 75%                              0.000000                         0.000000
# max                             44.000000                       238.000000
#
#        rowtype_plcment_start_piv_sum_n_days  \
# count                         124250.000000
# mean                               0.271131
# std                                1.388536
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                               44.000000
#
#        rowtype_program_primary_service_type_start_piv_sum_n_days  \
# count                                      124250.000000
# mean                                            0.234398
# std                                             0.521703
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            12.000000
#
#        rowtype_client_alert_start_piv_sum_n_days
# count                              124250.000000
# mean                                    0.049384
# std                                     0.219731
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     2.000000

# %%
data3avg=data3.filter(regex=r'_avg_n_days$', axis=1) #16 rows aggregate by the average of 6 month 
#data3avg.dtypes
data3avg.describe()
# Out:
#        rowtype_client_address_addition_piv_avg_n_days  \
# count                                   124250.000000
# mean                                         0.000105
# std                                          0.010228
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        rowtype_rp_end_piv_avg_n_days  rowtype_rp_start_piv_avg_n_days  \
# count                       124250.0                    124250.000000
# mean                             0.0                         0.000008
# std                              0.0                         0.002837
# min                              0.0                         0.000000
# 25%                              0.0                         0.000000
# 50%                              0.0                         0.000000
# 75%                              0.0                         0.000000
# max                              0.0                         1.000000
#
#        rowtype_progress_note_piv_avg_n_days  rowtype_diagnosis_piv_avg_n_days  \
# count                         124250.000000                     124250.000000
# mean                               0.108491                          0.000306
# std                                0.506376                          0.022336
# min                                0.000000                          0.000000
# 25%                                0.000000                          0.000000
# 50%                                0.000000                          0.000000
# 75%                                0.000000                          0.000000
# max                               13.000000                          3.000000
#
#        rowtype_medictn_start_piv_avg_n_days  \
# count                         124250.000000
# mean                               0.000113
# std                                0.011347
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                2.000000
#
#        rowtype_client_plan_start_piv_avg_n_days  \
# count                             124250.000000
# mean                                   0.000628
# std                                    0.025682
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                    0.000000
# max                                    2.000000
#
#        rowtype_client_plan_end_piv_avg_n_days  \
# count                           124250.000000
# mean                                 0.000282
# std                                  0.023564
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                  5.000000
#
#        rowtype_keyworker_change_piv_avg_n_days  \
# count                            124250.000000
# mean                                  0.000249
# std                                   0.021417
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.000000
# 75%                                   0.000000
# max                                   3.000000
#
#        rowtype_reference_piv_avg_n_days  rowtype_medictn_end_piv_avg_n_days  \
# count                     124250.000000                       124250.000000
# mean                           1.012346                            0.000016
# std                            0.112304                            0.004012
# min                            1.000000                            0.000000
# 25%                            1.000000                            0.000000
# 50%                            1.000000                            0.000000
# 75%                            1.000000                            0.000000
# max                            3.000000                            1.000000
#
#        rowtype_plcment_end_piv_avg_n_days  rowtype_incident_piv_avg_n_days  \
# count                       124250.000000                    124250.000000
# mean                             0.000032                         0.000620
# std                              0.008971                         0.027056
# min                              0.000000                         0.000000
# 25%                              0.000000                         0.000000
# 50%                              0.000000                         0.000000
# 75%                              0.000000                         0.000000
# max                              3.000000                         2.000000
#
#        rowtype_plcment_start_piv_avg_n_days  \
# count                         124250.000000
# mean                               0.000145
# std                                0.013306
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                2.000000
#
#        rowtype_program_primary_service_type_start_piv_avg_n_days  \
# count                                      124250.000000
# mean                                            0.000193
# std                                             0.015011
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             2.000000
#
#        rowtype_client_alert_start_piv_avg_n_days
# count                              124250.000000
# mean                                    0.000097
# std                                     0.009827
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                     1.000000

# %%
data3since=data3.filter(regex=r'_days_since$', axis=1) #16 rows 
#data3since.dtypes
data3since.describe()
# Out:
#        rowtype_client_address_addition_piv_days_since  \
# count                                   124293.000000
# mean                                      2739.183349
# std                                       1520.615379
# min                                          1.000000
# 25%                                        977.000000
# 50%                                       3650.000000
# 75%                                       3650.000000
# max                                       3650.000000
#
#        rowtype_rp_end_piv_days_since  rowtype_rp_start_piv_days_since  \
# count                  124293.000000                    124293.000000
# mean                     3606.998672                      3580.722961
# std                       383.555670                       484.926915
# min                         3.000000                         6.000000
# 25%                      3650.000000                      3650.000000
# 50%                      3650.000000                      3650.000000
# 75%                      3650.000000                      3650.000000
# max                      3650.000000                      3650.000000
#
#        rowtype_progress_note_piv_days_since  rowtype_diagnosis_piv_days_since  \
# count                         124293.000000                     124293.000000
# mean                             765.544986                       3279.420048
# std                             1405.982246                       1067.080564
# min                                1.000000                          1.000000
# 25%                                7.000000                       3650.000000
# 50%                               17.000000                       3650.000000
# 75%                              214.000000                       3650.000000
# max                             3650.000000                       3650.000000
#
#        rowtype_medictn_start_piv_days_since  \
# count                         124293.000000
# mean                            3448.989122
# std                              811.008192
# min                                1.000000
# 25%                             3650.000000
# 50%                             3650.000000
# 75%                             3650.000000
# max                             3650.000000
#
#        rowtype_client_plan_start_piv_days_since  \
# count                             124293.000000
# mean                                2221.846709
# std                                 1716.266979
# min                                    1.000000
# 25%                                  104.000000
# 50%                                 3650.000000
# 75%                                 3650.000000
# max                                 3650.000000
#
#        rowtype_client_plan_end_piv_days_since  \
# count                           124293.000000
# mean                              3200.658549
# std                               1166.203173
# min                                  1.000000
# 25%                               3650.000000
# 50%                               3650.000000
# 75%                               3650.000000
# max                               3650.000000
#
#        rowtype_keyworker_change_piv_days_since  \
# count                            124293.000000
# mean                               3041.146991
# std                                1326.926808
# min                                   1.000000
# 25%                                3650.000000
# 50%                                3650.000000
# 75%                                3650.000000
# max                                3650.000000
#
#        rowtype_reference_piv_days_since  rowtype_medictn_end_piv_days_since  \
# count                     124293.000000                       124293.000000
# mean                          13.047919                         3548.645724
# std                           80.304348                          583.803761
# min                            1.000000                            3.000000
# 25%                            1.000000                         3650.000000
# 50%                            1.000000                         3650.000000
# 75%                            1.000000                         3650.000000
# max                         3650.000000                         3650.000000
#
#        rowtype_plcment_end_piv_days_since  rowtype_incident_piv_days_since  \
# count                       124293.000000                    124293.000000
# mean                          3479.412034                      2905.017507
# std                            755.351573                      1431.819604
# min                              1.000000                         1.000000
# 25%                           3650.000000                      3650.000000
# 50%                           3650.000000                      3650.000000
# 75%                           3650.000000                      3650.000000
# max                           3650.000000                      3650.000000
#
#        rowtype_plcment_start_piv_days_since  \
# count                         124293.000000
# mean                            3287.630615
# std                             1068.291586
# min                                1.000000
# 25%                             3650.000000
# 50%                             3650.000000
# 75%                             3650.000000
# max                             3650.000000
#
#        rowtype_program_primary_service_type_start_piv_days_since  \
# count                                       124293.00000
# mean                                          2818.73231
# std                                           1490.63161
# min                                              1.00000
# 25%                                           3650.00000
# 50%                                           3650.00000
# 75%                                           3650.00000
# max                                           3650.00000
#
#        rowtype_client_alert_start_piv_days_since
# count                              124293.000000
# mean                                 3452.134505
# std                                   802.923055
# min                                     1.000000
# 25%                                  3650.000000
# 50%                                  3650.000000
# 75%                                  3650.000000
# max                                  3650.000000

# %%
data3lag=data3.filter(regex=r'_lag01$', axis=1)#16 rows aggregate number of one month ag, shift one down for '-piv' column
#data3lag.dtypes
data3lag.describe()
# Out:
#        rowtype_client_address_addition_piv_lag01  rowtype_rp_end_piv_lag01  \
# count                              109906.000000             109906.000000
# mean                                    0.042700                  0.003767
# std                                     0.207028                  0.100607
# min                                     0.000000                  0.000000
# 25%                                     0.000000                  0.000000
# 50%                                     0.000000                  0.000000
# 75%                                     0.000000                  0.000000
# max                                     4.000000                 10.000000
#
#        rowtype_rp_start_piv_lag01  rowtype_progress_note_piv_lag01  \
# count               109906.000000                    109906.000000
# mean                     0.005996                         6.397158
# std                      0.114507                        17.449678
# min                      0.000000                         0.000000
# 25%                      0.000000                         0.000000
# 50%                      0.000000                         1.000000
# 75%                      0.000000                         4.000000
# max                      8.000000                       303.000000
#
#        rowtype_diagnosis_piv_lag01  rowtype_medictn_start_piv_lag01  \
# count                109906.000000                    109906.000000
# mean                      0.033984                         0.025558
# std                       0.279048                         0.283787
# min                       0.000000                         0.000000
# 25%                       0.000000                         0.000000
# 50%                       0.000000                         0.000000
# 75%                       0.000000                         0.000000
# max                      16.000000                        18.000000
#
#        rowtype_client_plan_start_piv_lag01  rowtype_client_plan_end_piv_lag01  \
# count                         109906.00000                      109906.000000
# mean                               0.16243                           0.053600
# std                                0.59028                           0.401005
# min                                0.00000                           0.000000
# 25%                                0.00000                           0.000000
# 50%                                0.00000                           0.000000
# 75%                                0.00000                           0.000000
# max                               74.00000                          40.000000
#
#        rowtype_keyworker_change_piv_lag01  rowtype_reference_piv_lag01  \
# count                       109906.000000                109906.000000
# mean                             0.033856                    30.137636
# std                              0.241333                     4.911503
# min                              0.000000                     1.000000
# 25%                              0.000000                    30.000000
# 50%                              0.000000                    31.000000
# 75%                              0.000000                    31.000000
# max                              7.000000                    93.000000
#
#        rowtype_medictn_end_piv_lag01  rowtype_plcment_end_piv_lag01  \
# count                  109906.000000                  109906.000000
# mean                        0.010964                       0.038797
# std                         0.177579                       0.289993
# min                         0.000000                       0.000000
# 25%                         0.000000                       0.000000
# 50%                         0.000000                       0.000000
# 75%                         0.000000                       0.000000
# max                        16.000000                      12.000000
#
#        rowtype_incident_piv_lag01  rowtype_plcment_start_piv_lag01  \
# count               109906.000000                    109906.000000
# mean                     0.191018                         0.049934
# std                      1.102242                         0.343871
# min                      0.000000                         0.000000
# 25%                      0.000000                         0.000000
# 50%                      0.000000                         0.000000
# 75%                      0.000000                         0.000000
# max                     68.000000                        13.000000
#
#        rowtype_program_primary_service_type_start_piv_lag01  \
# count                                      109906.000000
# mean                                            0.027114
# std                                             0.191945
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                            12.000000
#
#        rowtype_client_alert_start_piv_lag01
# count                         109906.000000
# mean                               0.010491
# std                                0.103041
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                2.000000

# %%
From the above view, we can known that the difference among these 5 groups is aggregate function. All of them are talk about the same type of variables.

# %%
data3.plot.scatter(x='rowtype_client_address_addition_piv',y='rowtype_client_address_addition_piv_sum_n_days')
data3.loc[:,['rowtype_client_address_addition_piv','rowtype_client_address_addition_piv_sum_n_days']].corr()
# Out:
#                                                 rowtype_client_address_addition_piv  \
# rowtype_client_address_addition_piv                                        1.000000
# rowtype_client_address_addition_piv_sum_n_days                             0.365915
#
#                                                 rowtype_client_address_addition_piv_sum_n_days
# rowtype_client_address_addition_piv                                                   0.365915
# rowtype_client_address_addition_piv_sum_n_days                                        1.000000

# %% [raw]
# The 'data3' dataset is meansure the same variable in different scale, which can used to mearsure whether the incident related to the incident happend before.

# %%
data4=dataset.filter(regex=r'^medc_', axis=1)
data4.columns
#data4.describe()
# Out:
# Index(['medc_acqtype_1_piv', 'medc_acqtype_2_piv', 'medc_acqtype_3_piv',
#        'medc_admintype_10_piv', 'medc_admintype_08_piv',
#        'medc_admintype_09_piv', 'medc_admintype_04_piv',
#        'medc_admintype_05_piv', 'medc_admintype_06_piv',
#        'medc_admintype_07_piv', 'medc_admintype_11_piv',
#        'medc_admintype_01_piv', 'medc_admintype_02_piv',
#        'medc_admintype_03_piv', 'medc_levelofindependencetype_4_piv',
#        'medc_levelofindependencetype_5_piv',
#        'medc_levelofindependencetype_1_piv',
#        'medc_levelofindependencetype_2_piv',
#        'medc_levelofindependencetype_3_piv', 'medc_adminfreqid_1_piv',
#        'medc_adminfreqid_2_piv', 'medc_adminfreqid_3_piv',
#        'medc_adminfreqid_4_piv'],
#       dtype='object')

# %% [raw]
# There are 4 different column names, those columns are stable, which means not change with time. aggreagte each type of data to one column by put the type number in. Adding those aggregated columns to 'model'

# %%
count=[]
types=[1,2,3]
for i in range(numR):
    acq1=data4.loc[:,'medc_acqtype_1_piv']
    acq2=data4.loc[:,'medc_acqtype_2_piv']
    acq3=data4.loc[:,'medc_acqtype_3_piv']
    lst=[acq1[i]!=0,acq2[i]!=0,acq3[i]!=0]
    if True in lst:
        num=lst.index(True)
        count.append(types[num])
    else:
        count.append(0)
model['medc_acqtyp']=count 
model['medc_acqtyp'].value_counts()
# Out:
# 0    122252
# 1      1837
# 2       190
# 3        14
# Name: medc_acqtyp, dtype: int64

# %%
admintype=data4.loc[:,'medc_admintype_10_piv':'medc_admintype_03_piv']
adm=[]
typ=[10,8,9,4,5,6,7,11,1,2,3]
for i in range(numR):
    lst=[]
    row=list(admintype.iloc[i,:])
    if max(row)>0:
        num=row.index(max(row))
        adm.append(typ[num])
    else:
        adm.append(0)
print(len(adm))
model['medc_admintype']=adm
model['medc_admintype'].value_counts()
# Out:
# 124293
# 0     122252
# 1       1584
# 7        203
# 5         98
# 4         34
# 11        33
# 10        29
# 6         19
# 2         18
# 3         14
# 9          6
# 8          3
# Name: medc_admintype, dtype: int64

# %%
if sum(row)==max(row): #this shows that each type only have 1 value for a pk
        lst.append(0)
    else:
        lst.append(1)

# %%
levelofinde=data4.loc[:,'medc_levelofindependencetype_4_piv':'medc_levelofindependencetype_3_piv']
level=[]
typ=[4,5,1,2,3]
for i in range(numR):
    lst=[]
    row=list(levelofinde.iloc[i,:])
    if max(row)>0:
        num=row.index(max(row))
        level.append(typ[num])
    else:
        level.append(0)
model['medc_levelofindependencetype']=level
model['medc_levelofindependencetype'].value_counts()
# Out:
# 0    122252
# 4      1642
# 3       136
# 1       114
# 5        82
# 2        67
# Name: medc_levelofindependencetype, dtype: int64

# %%
admfid=data4.loc[:,'medc_adminfreqid_1_piv':'medc_adminfreqid_4_piv']
ids=[]
typ=[1,2,3,4]
for i in range(numR):
    lst=[]
    row=list(admfid.iloc[i,:])
    if max(row)>0:
        num=row.index(max(row))
        ids.append(typ[num])
    else:
        ids.append(0)
model['medc_adminfreqid']=ids
model['medc_adminfreqid'].value_counts()
# Out:
# 0    122252
# 3      1200
# 1       403
# 4       394
# 2        44
# Name: medc_adminfreqid, dtype: int64

# %%
for i in range(1,5-1):
    print((model.iloc[:,i]).equals(model.iloc[:,i+1]))
# Out:
# True
# True
# True

# %%
model.shape
# Out:
# (124293, 5)

# %% [raw]
# The attributes in 'data5' are objects, which means those attributes would be categori. there are no NA values

# %%
data5=dataset.filter(regex=r'^status_', axis=1)
data5.dtypes
# Out:
# status_placement                  124293
# status_client_plan                124293
# status_rp_mechanical_restraint    124293
# status_rp_restricted_access       124293
# status_rp_chemical_restraint      124293
# status_rp_other                   124293
# dtype: int64

# %%
levels={}
dicN={}
for name in data5.columns:
    value=data5.loc[:,name]
    lst=[]
    for v in value:
        if v not in lst:
            lst.append(v)
        levels[name]=[lst] # the name of levels of each object columns
        dicN[name]=len(lst) # number of levels of each object columns

# %%
dicN #from this result we can know that those attributes are factors with 3 or 2 levels
# Out:
# {'status_placement': 3,
#  'status_client_plan': 3,
#  'status_rp_mechanical_restraint': 2,
#  'status_rp_restricted_access': 3,
#  'status_rp_chemical_restraint': 3,
#  'status_rp_other': 3}

# %%
levels # The levels of each attributes.
# Out:
# {'status_placement': [['placement_none',
#    'placement_current',
#    'placement_ended']],
#  'status_client_plan': [['client_plan_none',
#    'client_plan_current',
#    'client_plan_ended']],
#  'status_rp_mechanical_restraint': [['rp_mechanical_restraint_none',
#    'rp_mechanical_restraint_current']],
#  'status_rp_restricted_access': [['rp_restricted_access_none',
#    'rp_restricted_access_current',
#    'rp_restricted_access_ended']],
#  'status_rp_chemical_restraint': [['rp_chemical_restraint_none',
#    'rp_chemical_restraint_current',
#    'rp_chemical_restraint_ended']],
#  'status_rp_other': [['rp_other_none', 'rp_other_current', 'rp_other_ended']]}

# %% [raw]
# Can add these 6 columns to 'model'
